#  (-37.84938563844925, 148.5266173740401),
#  (-75.96535280046257, -176.54407338570877),
#  (-20.957714175318685, -70.2005461679058),
#  (63.075795164070286, 136.8100858656715),
#  (-87.80309019845657, 169.85572796967307),
#  (-78.9429562132837, 160.20763738328856),
#  (-79.6734540416857, -8.113063053541737),
#  (-49.01993882394016, 146.3515347906373),
#  (20.177707828047545, -35.76090172098037),
#  (35.165882946036305, 161.3896894949666),
#  (21.074651369214592, -93.35499008332016),
#  (-60.71824163556376, -84.09349182675192),
#  ...]

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
cities
# Out:
# ['hobart',
#  'cabo san lucas',
#  'punta arenas',
#  'rio grande',
#  'filipesti',
#  'rikitea',
#  'sioux lookout',
#  'mount gambier',
#  'guerrero negro',
#  'vaini',
#  'mutsamudu',
#  'lasa',
#  'provideniya',
#  'camacha',
#  'norman wells',
#  'mataura',
#  'longyearbyen',
#  'shujalpur',
#  'lebu',
#  'asau',
#  'dikson',
#  'ushuaia',
#  'sao filipe',
#  'plouzane',
#  'mnogovershinnyy',
#  'albany',
#  'atuona',
#  'rocha',
#  'bluff',
#  'mahebourg',
#  'cherskiy',
#  'bredasdorp',
#  'busselton',
#  'nantucket',
#  'butaritari',
#  'puerto ayora',
#  'namatanai',
#  'hofn',
#  'kattivakkam',
#  'banjar',
#  'bethel',
#  'sao mateus',
#  'jiayuguan',
#  'marcona',
#  'avarua',
#  'guilin',
#  'asyut',
#  'frunze',
#  'ponta do sol',
#  'hilo',
#  'kapaa',
#  'buraydah',
#  'palana',
#  'suzu',
#  'arraial do cabo',
#  'vila franca do campo',
#  'college',
#  'victoria',
#  'tuktoyaktuk',
#  'lodwar',
#  'krasnoselkup',
#  'khatanga',
#  'bandarbeyla',
#  'hambantota',
#  'barrow',
#  'bahia honda',
#  'jamestown',
#  'loikaw',
#  'te anau',
#  'yellowknife',
#  'grand centre',
#  'mangrol',
#  'kodiak',
#  'severobaykalsk',
#  'bose',
#  'belushya guba',
#  'stromness',
#  'cape town',
#  'taiyuan',
#  'tasiilaq',
#  'show low',
#  'puerto baquerizo moreno',
#  'creston',
#  'port macquarie',
#  'samusu',
#  'fortuna',
#  'evensk',
#  'saleaula',
#  'chokurdakh',
#  'coihaique',
#  'gidole',
#  'ust-tsilma',
#  'okahandja',
#  'bambous virieux',
#  'yambio',
#  'kavieng',
#  'manikpur',
#  'westport',
#  'shenjiamen',
#  'cap malheureux',
#  'port elizabeth',
#  'parakai',
#  'bhadrachalam',
#  'ust-omchug',
#  'nikolskoye',
#  'qaanaaq',
#  'taolanaro',
#  'onguday',
#  'baghdad',
#  'kipushi',
#  'san patricio',
#  'pevek',
#  'alegrete',
#  'hami',
#  'vila do maio',
#  'taoudenni',
#  'maynooth',
#  'geraldton',
#  'san cristobal',
#  'cockburn town',
#  'aklavik',
#  'la rioja',
#  'nelson bay',
#  'ucluelet',
#  'dingle',
#  'ewa beach',
#  'georgetown',
#  'kanye',
#  'port alfred',
#  'praia',
#  'yerofey pavlovich',
#  'amderma',
#  'marzuq',
#  'ribeira grande',
#  'narsaq',
#  'illoqqortoormiut',
#  'hithadhoo',
#  'pregradnoye',
#  'mar del plata',
#  'katsuura',
#  'kyabe',
#  'margate',
#  'wairoa',
#  'gunnedah',
#  'puerto escondido',
#  'hokitika',
#  'birao',
#  'ayame',
#  'new norfolk',
#  'kruisfontein',
#  'bamiantong',
#  'celestun',
#  'malartic',
#  'hirson',
#  'alofi',
#  'port hardy',
#  'tambura',
#  'bismarck',
#  'puerto del rosario',
#  'tiksi',
#  'faanui',
#  'saint-philippe',
#  'sao joao da barra',
#  'ahome',
#  'belfast',
#  'bilibino',
#  'sentyabrskiy',
#  'tuatapere',
#  'high level',
#  'san juan',
#  'castro',
#  'petropolis',
#  'gwalior',
#  'carnarvon',
#  'mantsala',
#  'kawalu',
#  'hermanus',
#  'tsihombe',
#  'shimoda',
#  'adrar',
#  'caravelas',
#  'kasongo-lunda',
#  'chumikan',
#  'husavik',
#  'chapais',
#  'tilichiki',
#  'mount pleasant',
#  'erenhot',
#  'namtsy',
#  'leningradskiy',
#  'kahului',
#  'iqaluit',
#  'bahia blanca',
#  'tianpeng',
#  'ancud',
#  'kununurra',
#  'banmo',
#  'saskylakh',
#  'umzimvubu',
#  'vaitupu',
#  'clyde river',
#  'catalina',
#  'harper',
#  'esperance',
#  'chuy',
#  'lazaro cardenas',
#  'mariestad',
#  'virginia beach',
#  'touros',
#  'vila',
#  'nome',
#  'belz',
#  'sur',
#  'emba',
#  'ulverstone',
#  'jizan',
#  'saldanha',
#  'marawi',
#  'tyup',
#  'lakatoro',
#  'bathsheba',
#  'novyy svit',
#  'jiancheng',
#  'kaitangata',
#  'lolua',
#  'rockingham',
#  'torbay',
#  'tautira',
#  'kenai',
#  'nanortalik',
#  'babanusah',
#  'isangel',
#  'port blair',
#  'karratha',
#  'barentsburg',
#  'ahipara',
#  'nuuk',
#  'ouesso',
#  'egvekinot',
#  'dhidhdhoo',
#  'attawapiskat',
#  'qaqortoq',
#  'kropotkin',
#  'tarakan',
#  'salalah',
#  'gushikawa',
#  'kiama',
#  'palauig',
#  'hobyo',
#  'itoman',
#  'huambo',
#  'lompoc',
#  'lorengau',
#  'souillac',
#  'hohhot',
#  'grand gaube',
#  'okha',
#  'byron bay',
#  'mungwi',
#  'balkanabat',
#  'anuradhapura',
#  'broken hill',
#  'saint-augustin',
#  'coari',
#  'charleston',
#  'tabas',
#  'shihezi',
#  'east london',
#  'raduzhnyy',
#  'luderitz',
#  'wahran',
#  'dong hoi',
#  'udachnyy',
#  'lilongwe',
#  'mossendjo',
#  'humaita',
#  'aflu',
#  'constitucion',
#  'port lincoln',
#  'tecuala',
#  'kanashevo',
#  'madang',
#  'altay',
#  'kysyl-syr',
#  'ugoofaaru',
#  'chalmette',
#  'kedrovyy',
#  'sumbe',
#  'lariano',
#  'grindavik',
#  'yubari',
#  'inhambane',
#  'purpe',
#  'arlit',
#  'alice springs',
#  'santa rosa',
#  'mbanza-ngungu',
#  'sokolovyy',
#  'mehamn',
#  'shenkursk',
#  'siocon',
#  'deshnok',
#  'broome',
#  'calama',
#  'kumba',
#  'comodoro rivadavia',
#  'garowe',
#  'mys shmidta',
#  'ornskoldsvik',
#  'huarmey',
#  'mergui',
#  'shingu',
#  'araucaria',
#  'todos santos',
#  'biak',
#  'mecca',
#  'marsh harbour',
#  'sibu',
#  'les cayes',
#  'harlingen',
#  'cidreira',
#  'alekseyevka',
#  'xiaoyi',
#  'ondorhaan',
#  'guiratinga',
#  'santa vitoria do palmar',
#  'amahai',
#  'severodvinsk',
#  'muli',
#  'aykhal',
#  'nyurba',
#  'richards bay',
#  'morehead',
#  'sorland',
#  'andenes',
#  'dekalb',
#  'manono',
#  'ilulissat',
#  'kovdor',
#  'moron',
#  'kidal',
#  'vao',
#  'xadani',
#  'saint-francois',
#  'tiznit',
#  'vestmannaeyjar',
#  'kailua',
#  'bengkulu',
#  'terrace',
#  'antalaha',
#  'pisco',
#  'varkaus',
#  'hammerfest',
#  'hudiksvall',
#  'cururupu',
#  'komsomolskiy',
#  'bontang',
#  'mitsamiouli',
#  'salinas',
#  'solnechnyy',
#  'moree',
#  'borovskoy',
#  'vostok',
#  'hihifo',
#  'riihimaki',
#  'viligili',
#  'koshurnikovo',
#  'ilo',
#  'kogon',
#  'port keats',
#  'jasper',
#  'srandakan',
#  'airai',
#  'bay roberts',
#  'grand river south east',
#  'pangnirtung',
#  'bacolod',
#  'nyrob',
#  'sant feliu de guixols',
#  'aksum',
#  'parrita',
#  'barawe',
#  'khairagarh',
#  'ostrovnoy',
#  'vanimo',
#  'plettenberg bay',
#  'tezu',
#  'yumen',
#  'tasbuget',
#  'lagoa',
#  'martinez',
#  'sherbrooke',
#  'yar-sale',
#  'lalin',
#  'pochutla',
#  'doha',
#  'gamba',
#  'bonavista',
#  'sorvag',
#  'bria',
#  'upernavik',
#  'pauini',
#  'houston',
#  'half moon bay',
#  'turangi',
#  'naze',
#  'olinda',
#  'esil',
#  'kondinskoye',
#  'kaeo',
#  'samarai',
#  'abadan',
#  'brownsville',
#  'chaa-khol',
#  'iisalmi',
#  'kamaishi',
#  'bilma',
#  'olafsvik',
#  'pacifica',
#  'anadyr',
#  'carora',
#  'pombas',
#  'nizhneyansk',
#  'tuy hoa',
#  'ternate',
#  'skelleftea',
#  'waddan',
#  'omsukchan',
#  'caruray',
#  'oristano',
#  'zhuhai',
#  'brae',
#  'labytnangi',
#  'coquimbo',
#  'monrovia',
#  'bhubaneswar',
#  'cootehill',
#  'santa cruz',
#  'san martin',
#  'ajdabiya',
#  'umm kaddadah',
#  'kota bahru',
#  'codrington',
#  'key west',
#  'basco',
#  'avera',
#  'medicine hat',
#  'formoso do araguaia',
#  'veseloyarsk',
#  'missoula',
#  'oranjemund',
#  'lafia',
#  'amarante do maranhao',
#  'port saint lucie',
#  'severo-kurilsk',
#  'jimani',
#  'konokovo',
#  'olga',
#  'honiara',
#  'cayenne',
#  'canto do buriti',
#  'sirari',
#  'lakes entrance',
#  'iquique',
#  'khandyga',
#  'paraiso',
#  'coahuayana',
#  'uberaba',
#  'ati',
#  'pringsewu',
#  'kholodnyy',
#  'grimari',
#  'kikwit',
#  'cocorit',
#  'rawson',
#  'bambanglipuro',
#  'talnakh',
#  'toliary',
#  'vila velha',
#  'pascagoula',
#  'boyolangu',
#  'baiyin',
#  'dudinka',
#  'bolungarvik',
#  'matagami',
#  'filingue',
#  'malwan',
#  'erzin',
#  'wajir',
#  'langsa',
#  'qingyuan',
#  'dongsheng',
#  'albanel',
#  'muros',
#  'laguna',
#  'millinocket',
#  'lumby',
#  'klaksvik',
#  'asfi',
#  'mulege',
#  'pemangkat',
#  'tazovskiy',
#  'ulaangom',
#  'balykshi',
#  'turkan',
#  'sena madureira',
#  'murfreesboro',
#  'kantunilkin',
#  'novaya malykla',
#  'machiques',
#  'san rafael',
#  'chute-aux-outardes',
#  'rincon',
#  'vangaindrano',
#  'tabou',
#  'sakakah',
#  'ginda',
#  'samarinda',
#  'ishim',
#  'thompson',
#  'auki',
#  'chaman',
#  'zima',
#  'pravia',
#  'mulchen',
#  'cap-aux-meules',
#  'kamyshevatskaya',
#  'jiuquan',
#  'storforshei',
#  'haibowan',
#  'villazon',
#  'alta floresta',
#  'santiago',
#  'barra patuca',
#  'macau',
#  'utiroa',
#  'tambo',
#  'yokadouma',
#  'mwinilunga',
#  'balta',
#  'chagda',
#  'patan',
#  'nadym',
#  'gat',
#  'menongue',
#  'maceio',
#  'severnyy',
#  'copiapo',
#  'suslovo',
#  'arrecife',
#  'chingirlau',
#  'saint anthony',
#  'changli',
#  'muzhi',
#  'kisaran',
#  'iralaya',
#  'presidencia roque saenz pena',
#  'liwale',
#  'necochea',
#  'gorom-gorom',
#  'poum',
#  'colares',
#  'mazyr',
#  'muravlenko',
#  'adre',
#  'beyneu',
#  'rodez',
#  'xocali',
#  'dimitrovgrad',
#  'kavaratti',
#  'yeppoon',
#  'lewisporte',
#  'kawambwa',
#  'fairbanks',
#  'san matias',
#  'samalaeulu',
#  'jiddah',
#  'severo-yeniseyskiy',
#  'vicuna',
#  'melilla',
#  'salekhard',
#  'afonso bezerra',
#  'ketchenery',
#  'sao geraldo do araguaia',
#  'angola',
#  'flin flon',
#  'ardakan',
#  'nouakchott',
#  'suntar',
#  'barber',
#  'sharjah',
#  'beyne-heusay',
#  'gwembe',
#  'eston',
#  'russell',
#  'kilindoni',
#  'bonnyville',
#  'koumac',
#  'warri',
#  'karakendzha',
#  'banda aceh',
#  'acapulco',
#  'mount isa',
#  'ojinaga',
#  'saint-prosper',
#  'baturaja',
#  'golyshmanovo',
#  'mana',
#  'pitimbu',
#  'puro',
#  'osypenko',
#  'okhotsk',
#  'almaznyy',
#  'tauramena',
#  'det udom',
#  'quelimane',
#  'piano di sorrento',
#  'sonoita',
#  'pavlodar',
#  'barquisimeto',
#  'santa lucia',
#  'rosetta',
#  'satitoa',
#  'binzhou',
#  'petropavlovsk-kamchatskiy',
#  'cortez',
#  'rasipuram',
#  'kalmunai',
#  'abai',
#  'ziro',
#  'acajutla',
#  'sitka',
#  'aosta',
#  'fayaoue',
#  'bowen',
#  'beidao',
#  'wanning',
#  'los llanos de aridane',
#  'waingapu',
#  'picota',
#  'aba',
#  'oranjestad',
#  'namibe',
#  'bud',
#  'palizada',
#  'oktyabrskoye',
#  'mareeba',
#  'mogzon',
#  'imbituba',
#  'saint-joseph',
#  'alotau',
#  'wronki',
#  'nguiu',
#  'bereda',
#  'yamada',
#  'jalu',
#  'forestville',
#  'gazojak',
#  'jacareacanga',
#  'belmonte',
#  'xining',
#  'rusape',
#  'claremore',
#  'palabuhanratu',
#  'paragominas',
#  'mandalgovi',
#  'fort saint james',
#  'ust-nera',
#  'calatayud',
#  'valdivia',
#  'santa cruz cabralia',
#  'tigil',
#  'le vauclin',
#  'lewistown',
#  'watsa',
#  'rock springs',
#  'morden',
#  'alyangula',
#  'srikakulam',
#  'yorosso',
#  'rio gallegos',
#  'mezhdurechensk',
#  'aller',
#  'honningsvag',
#  'hasaki',
#  'launceston',
#  'pedro ii',
#  'suluq',
#  'sao sebastiao do cai',
#  'moen',
#  'portland',
#  'lasem',
#  'owando',
#  'bam',
#  'awbari',
#  'madona',
#  'lhokseumawe',
#  'deh rawud',
#  'piranhas',
#  'tra vinh',
#  'halalo',
#  'aksay',
#  'pocone',
#  'katherine',
#  'grafton',
#  'hovd',
#  'yulara',
#  'susacon',
#  'manaure',
#  'wichita falls',
#  'burnie',
#  'baijiantan',
#  'caucaia',
#  'dunedin',
#  'masty',
#  'sovetskiy',
#  'tabiauea',
#  'lamar',
#  'biryusinsk',
#  'candido mota',
#  'mibu',
#  'harduaganj',
#  'roura',
#  'shache',
#  'beringovskiy',
#  'bayanday',
#  'aswan',
#  'batemans bay',
#  'barcelos',
#  'pacific grove',
#  'lomovka',
#  'sanchor',
#  'starachowice',
#  'saint george',
#  'elko',
#  'sidi ali',
#  'hun',
#  'grand-lahou',
#  'bintulu',
#  'lakefield',
#  'santa fe',
#  'abu dhabi',
#  'ust-kamchatsk',
#  'wad madani',
#  'ulladulla',
#  'nouadhibou',
#  'mayumba',
#  'tunduru',
#  'fort nelson',
#  'praia da vitoria',
#  'lerwick',
#  'ixcatlan',
#  'santa cruz del sur',
#  'karoi',
#  'teya',
#  'nioro',
#  'birjand',
#  'hutchinson',
#  'bastia',
#  'coatlan',
#  'ipixuna',
#  'montepulciano',
#  'tripoli',
#  'abonnema',
#  'raga',
#  'karlstad',
#  'karaton',
#  'phan rang',
#  'pindiga',
#  'san policarpo',
#  'bacuit',
#  'tatarsk',
#  'camargo',
#  'bom conselho',
#  'karasjok',
#  'katete',
#  'svetlogorsk',
#  'benghazi',
#  'viedma',
#  'buqayq',
#  'varlamovo',
#  'choucheng',
#  'jati',
#  'ust-kuyga']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d129cc2706c7bafdd3f5e7724dc152ff

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
       
   # Group cities in sets of 50 for logging purposes
   if (i % 50 == 0 and i >= 50):
       set_count += 1
       record_count = 1
   # Create endpoint URL with each city
   city_url = url + "&q=" + city.replace(" ","+")
   
   # Log the url, record, and set numbers
   print(f"Processing Record {record_count} of Set {set_count} | {city}")
   # Add 1 to the record count
   record_count += 1
   # Run an API request for each of the cities
   try:
       city_weather = requests.get(city_url).json()
       # Parse out the max temp, humidity, and cloudiness
       city_lat = city_weather["coord"]["lat"]
       city_lng = city_weather["coord"]["lon"]
       city_max_temp = city_weather["main"]["temp_max"]
       city_humidity = city_weather["main"]["humidity"]
       city_clouds = city_weather["clouds"]["all"]
       city_wind = city_weather["wind"]["speed"]
       city_country = city_weather["sys"]["country"]
       city_weather_description = city_weather["weather"][0]["description"]      
           
           # Append the City information into city_data list
       city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Current Description": city_weather_description,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country})
   # If an error is experienced, skip the city
   except:
       print("City not found. Skipping...")
       pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | cabo san lucas
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | rio grande
# Processing Record 5 of Set 1 | filipesti
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | sioux lookout
# Processing Record 8 of Set 1 | mount gambier
# Processing Record 9 of Set 1 | guerrero negro
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 1 | lasa
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | camacha
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | shujalpur
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | asau
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | plouzane
# Processing Record 25 of Set 1 | mnogovershinnyy
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | rocha
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | nantucket
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | namatanai
# Processing Record 38 of Set 1 | hofn
# Processing Record 39 of Set 1 | kattivakkam
# Processing Record 40 of Set 1 | banjar
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | sao mateus
# Processing Record 43 of Set 1 | jiayuguan
# Processing Record 44 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | guilin
# Processing Record 47 of Set 1 | asyut
# Processing Record 48 of Set 1 | frunze
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | buraydah
# Processing Record 3 of Set 2 | palana
# Processing Record 4 of Set 2 | suzu
# City not found. Skipping...
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | college
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | lodwar
# Processing Record 11 of Set 2 | krasnoselkup
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | bandarbeyla
# Processing Record 14 of Set 2 | hambantota
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | bahia honda
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | loikaw
# Processing Record 19 of Set 2 | te anau
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 2 | mangrol
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | severobaykalsk
# Processing Record 25 of Set 2 | bose
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | stromness
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | taiyuan
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | show low
# Processing Record 32 of Set 2 | puerto baquerizo moreno
# Processing Record 33 of Set 2 | creston
# Processing Record 34 of Set 2 | port macquarie
# Processing Record 35 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | evensk
# Processing Record 38 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | coihaique
# Processing Record 41 of Set 2 | gidole
# Processing Record 42 of Set 2 | ust-tsilma
# Processing Record 43 of Set 2 | okahandja
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | yambio
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | manikpur
# Processing Record 48 of Set 2 | westport
# Processing Record 49 of Set 2 | shenjiamen
# Processing Record 50 of Set 2 | cap malheureux
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | parakai
# Processing Record 3 of Set 3 | bhadrachalam
# Processing Record 4 of Set 3 | ust-omchug
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 3 | onguday
# Processing Record 9 of Set 3 | baghdad
# Processing Record 10 of Set 3 | kipushi
# Processing Record 11 of Set 3 | san patricio
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | alegrete
# Processing Record 14 of Set 3 | hami
# Processing Record 15 of Set 3 | vila do maio
# Processing Record 16 of Set 3 | taoudenni
# Processing Record 17 of Set 3 | maynooth
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | san cristobal
# Processing Record 20 of Set 3 | cockburn town
# Processing Record 21 of Set 3 | aklavik
# Processing Record 22 of Set 3 | la rioja
# Processing Record 23 of Set 3 | nelson bay
# Processing Record 24 of Set 3 | ucluelet
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | ewa beach
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | kanye
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | praia
# Processing Record 31 of Set 3 | yerofey pavlovich
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | marzuq
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | pregradnoye
# Processing Record 39 of Set 3 | mar del plata
# Processing Record 40 of Set 3 | katsuura
# Processing Record 41 of Set 3 | kyabe
# Processing Record 42 of Set 3 | margate
# Processing Record 43 of Set 3 | wairoa
# Processing Record 44 of Set 3 | gunnedah
# Processing Record 45 of Set 3 | puerto escondido
# Processing Record 46 of Set 3 | hokitika
# Processing Record 47 of Set 3 | birao
# Processing Record 48 of Set 3 | ayame
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | bamiantong
# Processing Record 2 of Set 4 | celestun
# Processing Record 3 of Set 4 | malartic
# Processing Record 4 of Set 4 | hirson
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | port hardy
# Processing Record 7 of Set 4 | tambura
# Processing Record 8 of Set 4 | bismarck
# Processing Record 9 of Set 4 | puerto del rosario
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | sao joao da barra
# Processing Record 14 of Set 4 | ahome
# Processing Record 15 of Set 4 | belfast
# Processing Record 16 of Set 4 | bilibino
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | high level
# Processing Record 20 of Set 4 | san juan
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | petropolis
# Processing Record 23 of Set 4 | gwalior
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | mantsala
# Processing Record 26 of Set 4 | kawalu
# Processing Record 27 of Set 4 | hermanus
# Processing Record 28 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 4 | shimoda
# Processing Record 30 of Set 4 | adrar
# Processing Record 31 of Set 4 | caravelas
# Processing Record 32 of Set 4 | kasongo-lunda
# Processing Record 33 of Set 4 | chumikan
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | chapais
# Processing Record 36 of Set 4 | tilichiki
# Processing Record 37 of Set 4 | mount pleasant
# Processing Record 38 of Set 4 | erenhot
# Processing Record 39 of Set 4 | namtsy
# Processing Record 40 of Set 4 | leningradskiy
# Processing Record 41 of Set 4 | kahului
# Processing Record 42 of Set 4 | iqaluit
# Processing Record 43 of Set 4 | bahia blanca
# Processing Record 44 of Set 4 | tianpeng
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | kununurra
# Processing Record 47 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 48 of Set 4 | saskylakh
# Processing Record 49 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 5 | clyde river
# Processing Record 2 of Set 5 | catalina
# Processing Record 3 of Set 5 | harper
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | chuy
# Processing Record 6 of Set 5 | lazaro cardenas
# Processing Record 7 of Set 5 | mariestad
# Processing Record 8 of Set 5 | virginia beach
# Processing Record 9 of Set 5 | touros
# Processing Record 10 of Set 5 | vila
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | belz
# Processing Record 13 of Set 5 | sur
# Processing Record 14 of Set 5 | emba
# Processing Record 15 of Set 5 | ulverstone
# Processing Record 16 of Set 5 | jizan
# Processing Record 17 of Set 5 | saldanha
# Processing Record 18 of Set 5 | marawi
# Processing Record 19 of Set 5 | tyup
# Processing Record 20 of Set 5 | lakatoro
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | novyy svit
# Processing Record 23 of Set 5 | jiancheng
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 5 | rockingham
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | tautira
# Processing Record 29 of Set 5 | kenai
# Processing Record 30 of Set 5 | nanortalik
# Processing Record 31 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 5 | isangel
# Processing Record 33 of Set 5 | port blair
# Processing Record 34 of Set 5 | karratha
# Processing Record 35 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | ahipara
# Processing Record 37 of Set 5 | nuuk
# Processing Record 38 of Set 5 | ouesso
# Processing Record 39 of Set 5 | egvekinot
# Processing Record 40 of Set 5 | dhidhdhoo
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | qaqortoq
# Processing Record 43 of Set 5 | kropotkin
# Processing Record 44 of Set 5 | tarakan
# Processing Record 45 of Set 5 | salalah
# Processing Record 46 of Set 5 | gushikawa
# Processing Record 47 of Set 5 | kiama
# Processing Record 48 of Set 5 | palauig
# Processing Record 49 of Set 5 | hobyo
# Processing Record 50 of Set 5 | itoman
# Processing Record 1 of Set 6 | huambo
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | hohhot
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | okha
# Processing Record 8 of Set 6 | byron bay
# Processing Record 9 of Set 6 | mungwi
# Processing Record 10 of Set 6 | balkanabat
# Processing Record 11 of Set 6 | anuradhapura
# Processing Record 12 of Set 6 | broken hill
# Processing Record 13 of Set 6 | saint-augustin
# Processing Record 14 of Set 6 | coari
# Processing Record 15 of Set 6 | charleston
# Processing Record 16 of Set 6 | tabas
# Processing Record 17 of Set 6 | shihezi
# Processing Record 18 of Set 6 | east london
# Processing Record 19 of Set 6 | raduzhnyy
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 6 | dong hoi
# Processing Record 23 of Set 6 | udachnyy
# Processing Record 24 of Set 6 | lilongwe
# Processing Record 25 of Set 6 | mossendjo
# Processing Record 26 of Set 6 | humaita
# Processing Record 27 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | tecuala
# Processing Record 31 of Set 6 | kanashevo
# Processing Record 32 of Set 6 | madang
# Processing Record 33 of Set 6 | altay
# Processing Record 34 of Set 6 | kysyl-syr
# Processing Record 35 of Set 6 | ugoofaaru
# Processing Record 36 of Set 6 | chalmette
# Processing Record 37 of Set 6 | kedrovyy
# Processing Record 38 of Set 6 | sumbe
# Processing Record 39 of Set 6 | lariano
# Processing Record 40 of Set 6 | grindavik
# Processing Record 41 of Set 6 | yubari
# Processing Record 42 of Set 6 | inhambane
# Processing Record 43 of Set 6 | purpe
# Processing Record 44 of Set 6 | arlit
# Processing Record 45 of Set 6 | alice springs
# Processing Record 46 of Set 6 | santa rosa
# Processing Record 47 of Set 6 | mbanza-ngungu
# Processing Record 48 of Set 6 | sokolovyy
# Processing Record 49 of Set 6 | mehamn
# Processing Record 50 of Set 6 | shenkursk
# Processing Record 1 of Set 7 | siocon
# Processing Record 2 of Set 7 | deshnok
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | calama
# Processing Record 5 of Set 7 | kumba
# Processing Record 6 of Set 7 | comodoro rivadavia
# Processing Record 7 of Set 7 | garowe
# Processing Record 8 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 7 | ornskoldsvik
# Processing Record 10 of Set 7 | huarmey
# Processing Record 11 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 7 | shingu
# Processing Record 13 of Set 7 | araucaria
# Processing Record 14 of Set 7 | todos santos
# Processing Record 15 of Set 7 | biak
# Processing Record 16 of Set 7 | mecca
# Processing Record 17 of Set 7 | marsh harbour
# Processing Record 18 of Set 7 | sibu
# Processing Record 19 of Set 7 | les cayes
# Processing Record 20 of Set 7 | harlingen
# Processing Record 21 of Set 7 | cidreira
# Processing Record 22 of Set 7 | alekseyevka
# Processing Record 23 of Set 7 | xiaoyi
# Processing Record 24 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 7 | guiratinga
# Processing Record 26 of Set 7 | santa vitoria do palmar
# Processing Record 27 of Set 7 | amahai
# Processing Record 28 of Set 7 | severodvinsk
# Processing Record 29 of Set 7 | muli
# Processing Record 30 of Set 7 | aykhal
# Processing Record 31 of Set 7 | nyurba
# Processing Record 32 of Set 7 | richards bay
# Processing Record 33 of Set 7 | morehead
# Processing Record 34 of Set 7 | sorland
# Processing Record 35 of Set 7 | andenes
# Processing Record 36 of Set 7 | dekalb
# Processing Record 37 of Set 7 | manono
# Processing Record 38 of Set 7 | ilulissat
# Processing Record 39 of Set 7 | kovdor
# Processing Record 40 of Set 7 | moron
# Processing Record 41 of Set 7 | kidal
# Processing Record 42 of Set 7 | vao
# Processing Record 43 of Set 7 | xadani
# City not found. Skipping...
# Processing Record 44 of Set 7 | saint-francois
# Processing Record 45 of Set 7 | tiznit
# Processing Record 46 of Set 7 | vestmannaeyjar
# Processing Record 47 of Set 7 | kailua
# Processing Record 48 of Set 7 | bengkulu
# Processing Record 49 of Set 7 | terrace
# Processing Record 50 of Set 7 | antalaha
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | varkaus
# Processing Record 3 of Set 8 | hammerfest
# Processing Record 4 of Set 8 | hudiksvall
# Processing Record 5 of Set 8 | cururupu
# Processing Record 6 of Set 8 | komsomolskiy
# Processing Record 7 of Set 8 | bontang
# Processing Record 8 of Set 8 | mitsamiouli
# Processing Record 9 of Set 8 | salinas
# Processing Record 10 of Set 8 | solnechnyy
# Processing Record 11 of Set 8 | moree
# Processing Record 12 of Set 8 | borovskoy
# Processing Record 13 of Set 8 | vostok
# Processing Record 14 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 8 | riihimaki
# Processing Record 16 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 8 | koshurnikovo
# Processing Record 18 of Set 8 | ilo
# Processing Record 19 of Set 8 | kogon
# Processing Record 20 of Set 8 | port keats
# Processing Record 21 of Set 8 | jasper
# Processing Record 22 of Set 8 | srandakan
# Processing Record 23 of Set 8 | airai
# Processing Record 24 of Set 8 | bay roberts
# Processing Record 25 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 8 | pangnirtung
# Processing Record 27 of Set 8 | bacolod
# Processing Record 28 of Set 8 | nyrob
# Processing Record 29 of Set 8 | sant feliu de guixols
# Processing Record 30 of Set 8 | aksum
# Processing Record 31 of Set 8 | parrita
# Processing Record 32 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 8 | khairagarh
# Processing Record 34 of Set 8 | ostrovnoy
# Processing Record 35 of Set 8 | vanimo
# Processing Record 36 of Set 8 | plettenberg bay
# Processing Record 37 of Set 8 | tezu
# Processing Record 38 of Set 8 | yumen
# Processing Record 39 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 8 | lagoa
# Processing Record 41 of Set 8 | martinez
# Processing Record 42 of Set 8 | sherbrooke
# Processing Record 43 of Set 8 | yar-sale
# Processing Record 44 of Set 8 | lalin
# Processing Record 45 of Set 8 | pochutla
# Processing Record 46 of Set 8 | doha
# Processing Record 47 of Set 8 | gamba
# Processing Record 48 of Set 8 | bonavista
# Processing Record 49 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 8 | bria
# Processing Record 1 of Set 9 | upernavik
# Processing Record 2 of Set 9 | pauini
# Processing Record 3 of Set 9 | houston
# Processing Record 4 of Set 9 | half moon bay
# Processing Record 5 of Set 9 | turangi
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | olinda
# Processing Record 8 of Set 9 | esil
# Processing Record 9 of Set 9 | kondinskoye
# Processing Record 10 of Set 9 | kaeo
# Processing Record 11 of Set 9 | samarai
# Processing Record 12 of Set 9 | abadan
# Processing Record 13 of Set 9 | brownsville
# Processing Record 14 of Set 9 | chaa-khol
# City not found. Skipping...
# Processing Record 15 of Set 9 | iisalmi
# Processing Record 16 of Set 9 | kamaishi
# Processing Record 17 of Set 9 | bilma
# Processing Record 18 of Set 9 | olafsvik
# Processing Record 19 of Set 9 | pacifica
# Processing Record 20 of Set 9 | anadyr
# Processing Record 21 of Set 9 | carora
# Processing Record 22 of Set 9 | pombas
# Processing Record 23 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 9 | tuy hoa
# Processing Record 25 of Set 9 | ternate
# Processing Record 26 of Set 9 | skelleftea
# Processing Record 27 of Set 9 | waddan
# Processing Record 28 of Set 9 | omsukchan
# Processing Record 29 of Set 9 | caruray
# Processing Record 30 of Set 9 | oristano
# Processing Record 31 of Set 9 | zhuhai
# Processing Record 32 of Set 9 | brae
# Processing Record 33 of Set 9 | labytnangi
# Processing Record 34 of Set 9 | coquimbo
# Processing Record 35 of Set 9 | monrovia
# Processing Record 36 of Set 9 | bhubaneswar
# Processing Record 37 of Set 9 | cootehill
# Processing Record 38 of Set 9 | santa cruz
# Processing Record 39 of Set 9 | san martin
# Processing Record 40 of Set 9 | ajdabiya
# Processing Record 41 of Set 9 | umm kaddadah
# Processing Record 42 of Set 9 | kota bahru
# Processing Record 43 of Set 9 | codrington
# Processing Record 44 of Set 9 | key west
# Processing Record 45 of Set 9 | basco
# Processing Record 46 of Set 9 | avera
# Processing Record 47 of Set 9 | medicine hat
# Processing Record 48 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 9 | veseloyarsk
# Processing Record 50 of Set 9 | missoula
# Processing Record 1 of Set 10 | oranjemund
# Processing Record 2 of Set 10 | lafia
# Processing Record 3 of Set 10 | amarante do maranhao
# Processing Record 4 of Set 10 | port saint lucie
# Processing Record 5 of Set 10 | severo-kurilsk
# Processing Record 6 of Set 10 | jimani
# Processing Record 7 of Set 10 | konokovo
# Processing Record 8 of Set 10 | olga
# Processing Record 9 of Set 10 | honiara
# Processing Record 10 of Set 10 | cayenne
# Processing Record 11 of Set 10 | canto do buriti
# Processing Record 12 of Set 10 | sirari
# Processing Record 13 of Set 10 | lakes entrance
# Processing Record 14 of Set 10 | iquique
# Processing Record 15 of Set 10 | khandyga
# Processing Record 16 of Set 10 | paraiso
# Processing Record 17 of Set 10 | coahuayana
# Processing Record 18 of Set 10 | uberaba
# Processing Record 19 of Set 10 | ati
# Processing Record 20 of Set 10 | pringsewu
# Processing Record 21 of Set 10 | kholodnyy
# Processing Record 22 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 23 of Set 10 | kikwit
# Processing Record 24 of Set 10 | cocorit
# Processing Record 25 of Set 10 | rawson
# Processing Record 26 of Set 10 | bambanglipuro
# Processing Record 27 of Set 10 | talnakh
# Processing Record 28 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 10 | vila velha
# Processing Record 30 of Set 10 | pascagoula
# Processing Record 31 of Set 10 | boyolangu
# Processing Record 32 of Set 10 | baiyin
# Processing Record 33 of Set 10 | dudinka
# Processing Record 34 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 10 | matagami
# Processing Record 36 of Set 10 | filingue
# Processing Record 37 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 10 | erzin
# Processing Record 39 of Set 10 | wajir
# Processing Record 40 of Set 10 | langsa
# Processing Record 41 of Set 10 | qingyuan
# Processing Record 42 of Set 10 | dongsheng
# Processing Record 43 of Set 10 | albanel
# Processing Record 44 of Set 10 | muros
# Processing Record 45 of Set 10 | laguna
# Processing Record 46 of Set 10 | millinocket
# Processing Record 47 of Set 10 | lumby
# Processing Record 48 of Set 10 | klaksvik
# Processing Record 49 of Set 10 | asfi
# Processing Record 50 of Set 10 | mulege
# Processing Record 1 of Set 11 | pemangkat
# Processing Record 2 of Set 11 | tazovskiy
# Processing Record 3 of Set 11 | ulaangom
# Processing Record 4 of Set 11 | balykshi
# Processing Record 5 of Set 11 | turkan
# Processing Record 6 of Set 11 | sena madureira
# Processing Record 7 of Set 11 | murfreesboro
# Processing Record 8 of Set 11 | kantunilkin
# Processing Record 9 of Set 11 | novaya malykla
# Processing Record 10 of Set 11 | machiques
# Processing Record 11 of Set 11 | san rafael
# Processing Record 12 of Set 11 | chute-aux-outardes
# Processing Record 13 of Set 11 | rincon
# Processing Record 14 of Set 11 | vangaindrano
# Processing Record 15 of Set 11 | tabou
# Processing Record 16 of Set 11 | sakakah
# Processing Record 17 of Set 11 | ginda
# Processing Record 18 of Set 11 | samarinda
# Processing Record 19 of Set 11 | ishim
# Processing Record 20 of Set 11 | thompson
# Processing Record 21 of Set 11 | auki
# Processing Record 22 of Set 11 | chaman
# Processing Record 23 of Set 11 | zima
# Processing Record 24 of Set 11 | pravia
# Processing Record 25 of Set 11 | mulchen
# Processing Record 26 of Set 11 | cap-aux-meules
# Processing Record 27 of Set 11 | kamyshevatskaya
# Processing Record 28 of Set 11 | jiuquan
# Processing Record 29 of Set 11 | storforshei
# Processing Record 30 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 11 | villazon
# Processing Record 32 of Set 11 | alta floresta
# Processing Record 33 of Set 11 | santiago
# Processing Record 34 of Set 11 | barra patuca
# Processing Record 35 of Set 11 | macau
# Processing Record 36 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 11 | tambo
# Processing Record 38 of Set 11 | yokadouma
# Processing Record 39 of Set 11 | mwinilunga
# Processing Record 40 of Set 11 | balta
# Processing Record 41 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 11 | patan
# Processing Record 43 of Set 11 | nadym
# Processing Record 44 of Set 11 | gat
# Processing Record 45 of Set 11 | menongue
# Processing Record 46 of Set 11 | maceio
# Processing Record 47 of Set 11 | severnyy
# Processing Record 48 of Set 11 | copiapo
# Processing Record 49 of Set 11 | suslovo
# Processing Record 50 of Set 11 | arrecife
# Processing Record 1 of Set 12 | chingirlau
# Processing Record 2 of Set 12 | saint anthony
# Processing Record 3 of Set 12 | changli
# Processing Record 4 of Set 12 | muzhi
# Processing Record 5 of Set 12 | kisaran
# Processing Record 6 of Set 12 | iralaya
# Processing Record 7 of Set 12 | presidencia roque saenz pena
# Processing Record 8 of Set 12 | liwale
# Processing Record 9 of Set 12 | necochea
# Processing Record 10 of Set 12 | gorom-gorom
# Processing Record 11 of Set 12 | poum
# Processing Record 12 of Set 12 | colares
# Processing Record 13 of Set 12 | mazyr
# Processing Record 14 of Set 12 | muravlenko
# Processing Record 15 of Set 12 | adre
# Processing Record 16 of Set 12 | beyneu
# Processing Record 17 of Set 12 | rodez
# Processing Record 18 of Set 12 | xocali
# Processing Record 19 of Set 12 | dimitrovgrad
# Processing Record 20 of Set 12 | kavaratti
# Processing Record 21 of Set 12 | yeppoon
# Processing Record 22 of Set 12 | lewisporte
# Processing Record 23 of Set 12 | kawambwa
# Processing Record 24 of Set 12 | fairbanks
# Processing Record 25 of Set 12 | san matias
# Processing Record 26 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 12 | severo-yeniseyskiy
# Processing Record 29 of Set 12 | vicuna
# Processing Record 30 of Set 12 | melilla
# Processing Record 31 of Set 12 | salekhard
# Processing Record 32 of Set 12 | afonso bezerra
# Processing Record 33 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 34 of Set 12 | sao geraldo do araguaia
# Processing Record 35 of Set 12 | angola
# Processing Record 36 of Set 12 | flin flon
# Processing Record 37 of Set 12 | ardakan
# Processing Record 38 of Set 12 | nouakchott
# Processing Record 39 of Set 12 | suntar
# Processing Record 40 of Set 12 | barber
# Processing Record 41 of Set 12 | sharjah
# Processing Record 42 of Set 12 | beyne-heusay
# Processing Record 43 of Set 12 | gwembe
# Processing Record 44 of Set 12 | eston
# Processing Record 45 of Set 12 | russell
# Processing Record 46 of Set 12 | kilindoni
# Processing Record 47 of Set 12 | bonnyville
# Processing Record 48 of Set 12 | koumac
# Processing Record 49 of Set 12 | warri
# Processing Record 50 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 13 | banda aceh
# Processing Record 2 of Set 13 | acapulco
# Processing Record 3 of Set 13 | mount isa
# Processing Record 4 of Set 13 | ojinaga
# Processing Record 5 of Set 13 | saint-prosper
# Processing Record 6 of Set 13 | baturaja
# Processing Record 7 of Set 13 | golyshmanovo
# Processing Record 8 of Set 13 | mana
# Processing Record 9 of Set 13 | pitimbu
# Processing Record 10 of Set 13 | puro
# Processing Record 11 of Set 13 | osypenko
# Processing Record 12 of Set 13 | okhotsk
# Processing Record 13 of Set 13 | almaznyy
# Processing Record 14 of Set 13 | tauramena
# Processing Record 15 of Set 13 | det udom
# Processing Record 16 of Set 13 | quelimane
# Processing Record 17 of Set 13 | piano di sorrento
# Processing Record 18 of Set 13 | sonoita
# Processing Record 19 of Set 13 | pavlodar
# Processing Record 20 of Set 13 | barquisimeto
# Processing Record 21 of Set 13 | santa lucia
# Processing Record 22 of Set 13 | rosetta
# Processing Record 23 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 13 | binzhou
# Processing Record 25 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 13 | cortez
# Processing Record 27 of Set 13 | rasipuram
# Processing Record 28 of Set 13 | kalmunai
# Processing Record 29 of Set 13 | abai
# Processing Record 30 of Set 13 | ziro
# Processing Record 31 of Set 13 | acajutla
# Processing Record 32 of Set 13 | sitka
# Processing Record 33 of Set 13 | aosta
# Processing Record 34 of Set 13 | fayaoue
# Processing Record 35 of Set 13 | bowen
# Processing Record 36 of Set 13 | beidao
# Processing Record 37 of Set 13 | wanning
# Processing Record 38 of Set 13 | los llanos de aridane
# Processing Record 39 of Set 13 | waingapu
# Processing Record 40 of Set 13 | picota
# Processing Record 41 of Set 13 | aba
# Processing Record 42 of Set 13 | oranjestad
# Processing Record 43 of Set 13 | namibe
# Processing Record 44 of Set 13 | bud
# Processing Record 45 of Set 13 | palizada
# Processing Record 46 of Set 13 | oktyabrskoye
# Processing Record 47 of Set 13 | mareeba
# Processing Record 48 of Set 13 | mogzon
# Processing Record 49 of Set 13 | imbituba
# Processing Record 50 of Set 13 | saint-joseph
# Processing Record 1 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 14 | wronki
# Processing Record 3 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 14 | bereda
# Processing Record 5 of Set 14 | yamada
# Processing Record 6 of Set 14 | jalu
# Processing Record 7 of Set 14 | forestville
# Processing Record 8 of Set 14 | gazojak
# Processing Record 9 of Set 14 | jacareacanga
# Processing Record 10 of Set 14 | belmonte
# Processing Record 11 of Set 14 | xining
# Processing Record 12 of Set 14 | rusape
# Processing Record 13 of Set 14 | claremore
# Processing Record 14 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 14 | paragominas
# Processing Record 16 of Set 14 | mandalgovi
# Processing Record 17 of Set 14 | fort saint james
# Processing Record 18 of Set 14 | ust-nera
# Processing Record 19 of Set 14 | calatayud
# Processing Record 20 of Set 14 | valdivia
# Processing Record 21 of Set 14 | santa cruz cabralia
# Processing Record 22 of Set 14 | tigil
# Processing Record 23 of Set 14 | le vauclin
# Processing Record 24 of Set 14 | lewistown
# Processing Record 25 of Set 14 | watsa
# Processing Record 26 of Set 14 | rock springs
# Processing Record 27 of Set 14 | morden
# Processing Record 28 of Set 14 | alyangula
# Processing Record 29 of Set 14 | srikakulam
# Processing Record 30 of Set 14 | yorosso
# Processing Record 31 of Set 14 | rio gallegos
# Processing Record 32 of Set 14 | mezhdurechensk
# Processing Record 33 of Set 14 | aller
# Processing Record 34 of Set 14 | honningsvag
# Processing Record 35 of Set 14 | hasaki
# Processing Record 36 of Set 14 | launceston
# Processing Record 37 of Set 14 | pedro ii
# Processing Record 38 of Set 14 | suluq
# Processing Record 39 of Set 14 | sao sebastiao do cai
# Processing Record 40 of Set 14 | moen
# Processing Record 41 of Set 14 | portland
# Processing Record 42 of Set 14 | lasem
# Processing Record 43 of Set 14 | owando
# Processing Record 44 of Set 14 | bam
# Processing Record 45 of Set 14 | awbari
# Processing Record 46 of Set 14 | madona
# Processing Record 47 of Set 14 | lhokseumawe
# Processing Record 48 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 49 of Set 14 | piranhas
# Processing Record 50 of Set 14 | tra vinh
# Processing Record 1 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 15 | aksay
# Processing Record 3 of Set 15 | pocone
# Processing Record 4 of Set 15 | katherine
# Processing Record 5 of Set 15 | grafton
# Processing Record 6 of Set 15 | hovd
# Processing Record 7 of Set 15 | yulara
# Processing Record 8 of Set 15 | susacon
# Processing Record 9 of Set 15 | manaure
# Processing Record 10 of Set 15 | wichita falls
# Processing Record 11 of Set 15 | burnie
# Processing Record 12 of Set 15 | baijiantan
# Processing Record 13 of Set 15 | caucaia
# Processing Record 14 of Set 15 | dunedin
# Processing Record 15 of Set 15 | masty
# Processing Record 16 of Set 15 | sovetskiy
# Processing Record 17 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 15 | lamar
# Processing Record 19 of Set 15 | biryusinsk
# Processing Record 20 of Set 15 | candido mota
# Processing Record 21 of Set 15 | mibu
# Processing Record 22 of Set 15 | harduaganj
# Processing Record 23 of Set 15 | roura
# Processing Record 24 of Set 15 | shache
# Processing Record 25 of Set 15 | beringovskiy
# Processing Record 26 of Set 15 | bayanday
# Processing Record 27 of Set 15 | aswan
# Processing Record 28 of Set 15 | batemans bay
# Processing Record 29 of Set 15 | barcelos
# Processing Record 30 of Set 15 | pacific grove
# Processing Record 31 of Set 15 | lomovka
# Processing Record 32 of Set 15 | sanchor
# Processing Record 33 of Set 15 | starachowice
# Processing Record 34 of Set 15 | saint george
# Processing Record 35 of Set 15 | elko
# Processing Record 36 of Set 15 | sidi ali
# Processing Record 37 of Set 15 | hun
# Processing Record 38 of Set 15 | grand-lahou
# Processing Record 39 of Set 15 | bintulu
# Processing Record 40 of Set 15 | lakefield
# Processing Record 41 of Set 15 | santa fe
# Processing Record 42 of Set 15 | abu dhabi
# Processing Record 43 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 15 | wad madani
# Processing Record 45 of Set 15 | ulladulla
# Processing Record 46 of Set 15 | nouadhibou
# Processing Record 47 of Set 15 | mayumba
# Processing Record 48 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 49 of Set 15 | fort nelson
# Processing Record 50 of Set 15 | praia da vitoria
# Processing Record 1 of Set 16 | lerwick
# Processing Record 2 of Set 16 | ixcatlan
# City not found. Skipping...
# Processing Record 3 of Set 16 | santa cruz del sur
# Processing Record 4 of Set 16 | karoi
# Processing Record 5 of Set 16 | teya
# Processing Record 6 of Set 16 | nioro
# Processing Record 7 of Set 16 | birjand
# Processing Record 8 of Set 16 | hutchinson
# Processing Record 9 of Set 16 | bastia
# Processing Record 10 of Set 16 | coatlan
# City not found. Skipping...
# Processing Record 11 of Set 16 | ipixuna
# Processing Record 12 of Set 16 | montepulciano
# Processing Record 13 of Set 16 | tripoli
# Processing Record 14 of Set 16 | abonnema
# Processing Record 15 of Set 16 | raga
# Processing Record 16 of Set 16 | karlstad
# Processing Record 17 of Set 16 | karaton
# Processing Record 18 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 16 | pindiga
# Processing Record 20 of Set 16 | san policarpo
# Processing Record 21 of Set 16 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 16 | tatarsk
# Processing Record 23 of Set 16 | camargo
# Processing Record 24 of Set 16 | bom conselho
# Processing Record 25 of Set 16 | karasjok
# Processing Record 26 of Set 16 | katete
# Processing Record 27 of Set 16 | svetlogorsk
# Processing Record 28 of Set 16 | benghazi
# Processing Record 29 of Set 16 | viedma
# Processing Record 30 of Set 16 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 16 | varlamovo
# Processing Record 32 of Set 16 | choucheng
# City not found. Skipping...
# Processing Record 33 of Set 16 | jati
# Processing Record 34 of Set 16 | ust-kuyga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 48.99,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'AU'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 84,
#   'Current Description': 'broken clouds',
#   'Humidity': 34,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'MX'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 57.2,
#   'Current Description': 'clear sky',
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'CL'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 71.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Country': 'BR'},
#  {'City': 'Filipesti',
#   'Lat': 46.75,
#   'Lng': 26.8833,
#   'Max Temp': 43,
#   'Current Description': 'light rain',
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'RO'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 78.35,
#   'Current Description': 'light rain',
#   'Humidity': 74,
#   'Cloudiness': 8,
#   'Wind Speed': 8.57,
#   'Country': 'PF'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 37.4,
#   'Current Description': 'mist',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'CA'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 51.8,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'AU'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 67.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 57,
#   'Cloudiness': 98,
#   'Wind Speed': 16.71,
#   'Country': 'MX'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 80.6,
#   'Current Description': 'few clouds',
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'TO'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 48,
#   'Current Description': 'mist',
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'IT'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 10.81,
#   'Current Description': 'snow',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 29.86,
#   'Country': 'RU'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 64.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'PT'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 5,
#   'Current Description': 'clear sky',
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'CA'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 50,
#   'Current Description': 'broken clouds',
#   'Humidity': 98,
#   'Cloudiness': 82,
#   'Wind Speed': 1.99,
#   'Country': 'NZ'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 19.4,
#   'Current Description': 'broken clouds',
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'SJ'},
#  {'City': 'Shujalpur',
#   'Lat': 23.4,
#   'Lng': 76.7167,
#   'Max Temp': 81.7,
#   'Current Description': 'broken clouds',
#   'Humidity': 22,
#   'Cloudiness': 53,
#   'Wind Speed': 4.21,
#   'Country': 'IN'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 59.63,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 13.47,
#   'Country': 'CL'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 42.01,
#   'Current Description': 'light rain',
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 3.49,
#   'Country': 'RO'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 30.79,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 26.08,
#   'Country': 'RU'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 50,
#   'Current Description': 'broken clouds',
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'AR'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 76.03,
#   'Current Description': 'clear sky',
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 8.88,
#   'Country': 'CV'},
#  {'City': 'Plouzane',
#   'Lat': 48.3833,
#   'Lng': -4.6167,
#   'Max Temp': 41,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'FR'},
#  {'City': 'Mnogovershinnyy',
#   'Lat': 53.9353,
#   'Lng': 139.9242,
#   'Max Temp': 15.94,
#   'Current Description': 'broken clouds',
#   'Humidity': 88,
#   'Cloudiness': 74,
#   'Wind Speed': 7.2,
#   'Country': 'RU'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 64.99,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 10.63,
#   'Country': 'US'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.71,
#   'Current Description': 'few clouds',
#   'Humidity': 76,
#   'Cloudiness': 19,
#   'Wind Speed': 17.43,
#   'Country': 'PF'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 62.82,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 21.9,
#   'Country': 'UY'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 50,
#   'Current Description': 'light rain',
#   'Humidity': 98,
#   'Cloudiness': 22,
#   'Wind Speed': 1.99,
#   'Country': 'NZ'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 77,
#   'Current Description': 'broken clouds',
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'MU'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -18.18,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Country': 'RU'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 57.2,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'ZA'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 61,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'AU'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 46.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'US'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.94,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 31,
#   'Wind Speed': 9.71,
#   'Country': 'KI'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 80.6,
#   'Current Description': 'scattered clouds',
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'EC'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 78.04,
#   'Current Description': 'light rain',
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.2,
#   'Country': 'PG'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 38.05,
#   'Current Description': 'light rain',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 17.76,
#   'Country': 'IS'},
#  {'City': 'Kattivakkam',
#   'Lat': 13.2167,
#   'Lng': 80.3167,
#   'Max Temp': 82.4,
#   'Current Description': 'mist',
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'IN'},
#  {'City': 'Banjar',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 80.6,
#   'Current Description': 'few clouds',
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'ID'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 55.4,
#   'Current Description': 'light rain',
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Sao Mateus',
#   'Lat': -18.7161,
#   'Lng': -39.8589,
#   'Max Temp': 74.5,
#   'Current Description': 'few clouds',
#   'Humidity': 81,
#   'Cloudiness': 12,
#   'Wind Speed': 4.85,
#   'Country': 'BR'},
#  {'City': 'Jiayuguan',
#   'Lat': 39.8167,
#   'Lng': 98.3,
#   'Max Temp': 40.64,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 3.83,
#   'Country': 'CN'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 82.4,
#   'Current Description': 'moderate rain',
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 4.61,
#   'Country': 'CK'},
#  {'City': 'Guilin',
#   'Lat': 25.2819,
#   'Lng': 110.2864,
#   'Max Temp': 60.8,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 0.87,
#   'Country': 'CN'},
#  {'City': 'Asyut',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 59,
#   'Current Description': 'clear sky',
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'EG'},
#  {'City': 'Frunze',
#   'Lat': 48.6686,
#   'Lng': 38.7544,
#   'Max Temp': 49.26,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.93,
#   'Country': 'UA'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 63,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'PT'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 80.6,
#   'Current Description': 'clear sky',
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75,
#   'Current Description': 'light rain',
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 69.8,
#   'Current Description': 'clear sky',
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'SA'},
#  {'City': 'Palana',
#   'Lat': 59.1167,
#   'Lng': 159.9667,
#   'Max Temp': 5.99,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 2.21,
#   'Country': 'RU'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 78.8,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'BR'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 62.6,
#   'Current Description': 'broken clouds',
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'PT'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 26.01,
#   'Current Description': 'overcast clouds',
#   'Humidity': 30,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 73,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 93,
#   'Wind Speed': 8.84,
#   'Country': 'HK'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -5.8,
#   'Current Description': 'clear sky',
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'CA'},
#  {'City': 'Lodwar',
#   'Lat': 3.1191,
#   'Lng': 35.5973,
#   'Max Temp': 85.35,
#   'Current Description': 'broken clouds',
#   'Humidity': 47,
#   'Cloudiness': 66,
#   'Wind Speed': 20.85,
#   'Country': 'KE'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 31.55,
#   'Current Description': 'snow',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 21.61,
#   'Country': 'RU'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 17.02,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 12.21,
#   'Country': 'RU'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 79.07,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 8,
#   'Wind Speed': 7.34,
#   'Country': 'SO'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 78.22,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 92,
#   'Wind Speed': 1.52,
#   'Country': 'LK'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -13,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Bahia Honda',
#   'Lat': 22.9036,
#   'Lng': -83.1592,
#   'Max Temp': 88.77,
#   'Current Description': 'few clouds',
#   'Humidity': 50,
#   'Cloudiness': 17,
#   'Wind Speed': 12.93,
#   'Country': 'CU'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 64.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'US'},
#  {'City': 'Loikaw',
#   'Lat': 19.6742,
#   'Lng': 97.2094,
#   'Max Temp': 69.58,
#   'Current Description': 'scattered clouds',
#   'Humidity': 74,
#   'Cloudiness': 27,
#   'Wind Speed': 1.92,
#   'Country': 'MM'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 50.79,
#   'Current Description': 'broken clouds',
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 0.78,
#   'Country': 'NZ'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 9,
#   'Current Description': 'light snow',
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 78.51,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 12.06,
#   'Country': 'IN'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 39.2,
#   'Current Description': 'moderate rain',
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Country': 'US'},
#  {'City': 'Severobaykalsk',
#   'Lat': 55.65,
#   'Lng': 109.3167,
#   'Max Temp': 6.12,
#   'Current Description': 'clear sky',
#   'Humidity': 84,
#   'Cloudiness': 10,
#   'Wind Speed': 5.08,
#   'Country': 'RU'},
#  {'City': 'Bose',
#   'Lat': 45.4612,
#   'Lng': 8.0137,
#   'Max Temp': 48.99,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'IT'},
#  {'City': 'Stromness',
#   'Lat': 58.965,
#   'Lng': -3.296,
#   'Max Temp': 33.8,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 9,
#   'Wind Speed': 3.44,
#   'Country': 'GB'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 66,
#   'Current Description': 'clear sky',
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ZA'},
#  {'City': 'Taiyuan',
#   'Lat': 37.8694,
#   'Lng': 112.5603,
#   'Max Temp': 50,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 98,
#   'Wind Speed': 2.24,
#   'Country': 'CN'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 28.4,
#   'Current Description': 'clear sky',
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'GL'},
#  {'City': 'Show Low',
#   'Lat': 34.2542,
#   'Lng': -110.0298,
#   'Max Temp': 69.01,
#   'Current Description': 'clear sky',
#   'Humidity': 8,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Puerto Baquerizo Moreno',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 82.4,
#   'Current Description': 'broken clouds',
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'EC'},
#  {'City': 'Creston',
#   'Lat': 41.0586,
#   'Lng': -94.3614,
#   'Max Temp': 64.4,
#   'Current Description': 'clear sky',
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 50,
#   'Current Description': 'clear sky',
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 8.61,
#   'Country': 'AU'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 59,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'US'},
#  {'City': 'Evensk',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': -0.35,
#   'Current Description': 'few clouds',
#   'Humidity': 77,
#   'Cloudiness': 16,
#   'Wind Speed': 10.09,
#   'Country': 'RU'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -12.96,
#   'Current Description': 'broken clouds',
#   'Humidity': 97,
#   'Cloudiness': 59,
#   'Wind Speed': 9.82,
#   'Country': 'RU'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 62.6,
#   'Current Description': 'light rain',
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CL'},
#  {'City': 'Gidole',
#   'Lat': 5.65,
#   'Lng': 37.3667,
#   'Max Temp': 57.38,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 59,
#   'Wind Speed': 4.03,
#   'Country': 'ET'},
#  {'City': 'Ust-Tsilma',
#   'Lat': 65.441,
#   'Lng': 52.1498,
#   'Max Temp': 34.2,
#   'Current Description': 'scattered clouds',
#   'Humidity': 71,
#   'Cloudiness': 35,
#   'Wind Speed': 12.33,
#   'Country': 'RU'},
#  {'City': 'Okahandja',
#   'Lat': -21.9833,
#   'Lng': 16.9167,
#   'Max Temp': 66,
#   'Current Description': 'clear sky',
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'NA'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79,
#   'Current Description': 'broken clouds',
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'MU'},
#  {'City': 'Yambio',
#   'Lat': 4.5721,
#   'Lng': 28.3955,
#   'Max Temp': 68.76,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.62,
#   'Country': 'SS'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 77.52,
#   'Current Description': 'light rain',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'PG'},
#  {'City': 'Manikpur',
#   'Lat': 25.0667,
#   'Lng': 81.1167,
#   'Max Temp': 82.22,
#   'Current Description': 'scattered clouds',
#   'Humidity': 26,
#   'Cloudiness': 38,
#   'Wind Speed': 2.77,
#   'Country': 'IN'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 50,
#   'Current Description': 'moderate rain',
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US'},
#  {'City': 'Shenjiamen',
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp': 60.33,
#   'Current Description': 'moderate rain',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 17.63,
#   'Country': 'CN'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 79,
#   'Current Description': 'light rain',
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Country': 'MU'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 57.99,
#   'Current Description': 'broken clouds',
#   'Humidity': 87,
#   'Cloudiness': 77,
#   'Wind Speed': 1.01,
#   'Country': 'ZA'},
#  {'City': 'Parakai',
#   'Lat': -36.65,
#   'Lng': 174.4333,
#   'Max Temp': 66.99,
#   'Current Description': 'few clouds',
#   'Humidity': 98,
#   'Cloudiness': 23,
#   'Wind Speed': 4,
#   'Country': 'NZ'},
#  {'City': 'Bhadrachalam',
#   'Lat': 17.6667,
#   'Lng': 80.8833,
#   'Max Temp': 81.05,
#   'Current Description': 'few clouds',
#   'Humidity': 69,
#   'Cloudiness': 16,
#   'Wind Speed': 4.61,
#   'Country': 'IN'},
#  {'City': 'Ust-Omchug',
#   'Lat': 61.15,
#   'Lng': 149.6333,
#   'Max Temp': -3.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95,
#   'Country': 'RU'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 43,
#   'Current Description': 'light rain',
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 22.95,
#   'Current Description': 'snow',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Country': 'GL'},
#  {'City': 'Onguday',
#   'Lat': 50.75,
#   'Lng': 86.15,
#   'Max Temp': 33.44,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 2.62,
#   'Country': 'RU'},
#  {'City': 'Baghdad',
#   'Lat': 33.3406,
#   'Lng': 44.4009,
#   'Max Temp': 57.2,
#   'Current Description': 'clear sky',
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'IQ'},
#  {'City': 'Kipushi',
#   'Lat': -11.7667,
#   'Lng': 27.2333,
#   'Max Temp': 59.09,
#   'Current Description': 'scattered clouds',
#   'Humidity': 97,
#   'Cloudiness': 45,
#   'Wind Speed': 4.52,
#   'Country': 'CD'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 87.8,
#   'Current Description': 'broken clouds',
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -17.48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Country': 'RU'},
#  {'City': 'Alegrete',
#   'Lat': -29.7831,
#   'Lng': -55.7919,
#   'Max Temp': 66.49,
#   'Current Description': 'overcast clouds',
#   'Humidity': 67,
#   'Cloudiness': 98,
#   'Wind Speed': 13.2,
#   'Country': 'BR'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 53.44,
#   'Current Description': 'overcast clouds',
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 11.12,
#   'Country': 'CN'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 75.2,
#   'Current Description': 'clear sky',
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'CV'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 88.95,
#   'Current Description': 'clear sky',
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 6.62,
#   'Country': 'ML'},
#  {'City': 'Maynooth',
#   'Lat': 53.385,
#   'Lng': -6.5936,
#   'Max Temp': 39.2,
#   'Current Description': 'heavy intensity rain',
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'IE'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 73.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'AU'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 89.6,
#   'Current Description': 'scattered clouds',
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'VE'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 78.8,
#   'Current Description': 'scattered clouds',
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'TC'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 8.6,
#   'Current Description': 'few clouds',
#   'Humidity': 36,
#   'Cloudiness': 13,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'La Rioja',
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 46.4,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'ES'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 52,
#   'Current Description': 'few clouds',
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'AU'},
#  {'City': 'Ucluelet',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 48.99,
#   'Current Description': 'few clouds',
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'CA'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 74.71,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 5.93,
#   'Country': 'PH'},
#  {'City': 'Ewa Beach',
#   'Lat': 21.3156,
#   'Lng': -158.0072,
#   'Max Temp': 78.8,
#   'Current Description': 'broken clouds',
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 81,
#   'Current Description': 'scattered clouds',
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'MY'},
#  {'City': 'Kanye',
#   'Lat': -24.9667,
#   'Lng': 25.3327,
#   'Max Temp': 65.35,
#   'Current Description': 'clear sky',
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 1.83,
#   'Country': 'BW'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 66.58,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 3.71,
#   'Country': 'ZA'},
#  {'City': 'Praia',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 75.2,
#   'Current Description': 'clear sky',
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'CV'},
#  {'City': 'Yerofey Pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 11.17,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 3.91,
#   'Country': 'RU'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 66.47,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 3,
#   'Wind Speed': 6.22,
#   'Country': 'YE'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 62.6,
#   'Current Description': 'broken clouds',
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'PT'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 50,
#   'Current Description': 'clear sky',
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'GL'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.67,
#   'Current Description': 'overcast clouds',
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 11.01,
#   'Country': 'MV'},
#  {'City': 'Pregradnoye',
#   'Lat': 45.8218,
#   'Lng': 41.7469,
#   'Max Temp': 48.11,
#   'Current Description': 'light rain',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Country': 'RU'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 66.2,
#   'Current Description': 'few clouds',
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'AR'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 53.6,
#   'Current Description': 'few clouds',
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'JP'},
#  {'City': 'Kyabe',
#   'Lat': 9.4515,
#   'Lng': 18.9449,
#   'Max Temp': 88.41,
#   'Current Description': 'broken clouds',
#   'Humidity': 8,
#   'Cloudiness': 82,
#   'Wind Speed': 2.8,
#   'Country': 'TD'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 39,
#   'Current Description': 'overcast clouds',
#   'Humidity': 70,
#   'Cloudiness': 96,
#   'Wind Speed': 1.01,
#   'Country': 'GB'},
#  {'City': 'Wairoa',
#   'Lat': -39.0333,
#   'Lng': 177.3667,
#   'Max Temp': 64,
#   'Current Description': 'broken clouds',
#   'Humidity': 97,
#   'Cloudiness': 79,
#   'Wind Speed': 1.99,
#   'Country': 'NZ'},
#  {'City': 'Gunnedah',
#   'Lat': -30.9833,
#   'Lng': 150.25,
#   'Max Temp': 43,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AU'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 86,
#   'Current Description': 'few clouds',
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MX'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 55.87,
#   'Current Description': 'light rain',
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 7.34,
#   'Country': 'NZ'},
#  {'City': 'Birao',
#   'Lat': 10.2849,
#   'Lng': 22.7882,
#   'Max Temp': 82.49,
#   'Current Description': 'overcast clouds',
#   'Humidity': 12,
#   'Cloudiness': 100,
#   'Wind Speed': 6.04,
#   'Country': 'CF'},
#  {'City': 'Ayame',
#   'Lat': 5.6083,
#   'Lng': -3.1563,
#   'Max Temp': 77.92,
#   'Current Description': 'light rain',
#   'Humidity': 91,
#   'Cloudiness': 36,
#   'Wind Speed': 4.54,
#   'Country': 'CI'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 48.99,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Country': 'AU'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 57.99,
#   'Current Description': 'broken clouds',
#   'Humidity': 87,
#   'Cloudiness': 73,
#   'Wind Speed': 1.01,
#   'Country': 'ZA'},
#  {'City': 'Bamiantong',
#   'Lat': 44.9333,
#   'Lng': 130.5333,
#   'Max Temp': 50.58,
#   'Current Description': 'overcast clouds',
#   'Humidity': 56,
#   'Cloudiness': 98,
#   'Wind Speed': 9.8,
#   'Country': 'CN'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 84.09,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 14.16,
#   'Country': 'MX'},
#  {'City': 'Malartic',
#   'Lat': 48.1335,
#   'Lng': -78.1328,
#   'Max Temp': 72,
#   'Current Description': 'broken clouds',
#   'Humidity': 35,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'CA'},
#  {'City': 'Hirson',
#   'Lat': 49.9226,
#   'Lng': 4.0826,
#   'Max Temp': 35.01,
#   'Current Description': 'scattered clouds',
#   'Humidity': 82,
#   'Cloudiness': 30,
#   'Wind Speed': 1.01,
#   'Country': 'FR'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 77,
#   'Current Description': 'few clouds',
#   'Humidity': 88,
#   'Cloudiness': 18,
#   'Wind Speed': 5.75,
#   'Country': 'NU'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 46.4,
#   'Current Description': 'few clouds',
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'CA'},
#  {'City': 'Tambura',
#   'Lat': 5.6,
#   'Lng': 27.4667,
#   'Max Temp': 76.06,
#   'Current Description': 'light rain',
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 6.24,
#   'Country': 'SS'},
#  {'City': 'Bismarck',
#   'Lat': 46.8083,
#   'Lng': -100.7837,
#   'Max Temp': 44.6,
#   'Current Description': 'light rain',
#   'Humidity': 57,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'US'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 68,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'ES'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 4.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 7.92,
#   'Country': 'RU'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.47,
#   'Current Description': 'overcast clouds',
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 11.25,
#   'Country': 'PF'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 77,
#   'Current Description': 'clear sky',
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'RE'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 78.8,
#   'Current Description': 'clear sky',
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'BR'},
#  {'City': 'Ahome',
#   'Lat': 25.9167,
#   'Lng': -109.1833,
#   'Max Temp': 87.01,
#   'Current Description': 'broken clouds',
#   'Humidity': 39,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'MX'},
#  {'City': 'Belfast',
#   'Lat': 54.5833,
#   'Lng': -5.9333,
#   'Max Temp': 41,
#   'Current Description': 'broken clouds',
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'GB'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -10.88,
#   'Current Description': 'few clouds',
#   'Humidity': 83,
#   'Cloudiness': 22,
#   'Wind Speed': 1.54,
#   'Country': 'RU'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 50,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 86,
#   'Wind Speed': 1.99,
#   'Country': 'NZ'},
#  {'City': 'High Level',
#   'Lat': 58.5169,
#   'Lng': -117.136,
#   'Max Temp': 23,
#   'Current Description': 'light snow',
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'San Juan',
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp': 76.03,
#   'Current Description': 'clear sky',
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 6.82,
#   'Country': 'AR'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 68.38,
#   'Current Description': 'few clouds',
#   'Humidity': 67,
#   'Cloudiness': 13,
#   'Wind Speed': 3.87,
#   'Country': 'BR'},
#  {'City': 'Petropolis',
#   'Lat': 59.8944,
#   'Lng': 30.2642,
#   'Max Temp': 43,
#   'Current Description': 'light rain',
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU'},
#  {'City': 'Gwalior',
#   'Lat': 26.2236,
#   'Lng': 78.1792,
#   'Max Temp': 81.91,
#   'Current Description': 'clear sky',
#   'Humidity': 21,
#   'Cloudiness': 2,
#   'Wind Speed': 5.82,
#   'Country': 'IN'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 78.8,
#   'Current Description': 'scattered clouds',
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'AU'},
#  {'City': 'Mantsala',
#   'Lat': 60.6609,
#   'Lng': 25.2838,
#   'Max Temp': 42.8,
#   'Current Description': 'few clouds',
#   'Humidity': 45,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'FI'},
#  {'City': 'Kawalu',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 72.28,
#   'Current Description': 'broken clouds',
#   'Humidity': 97,
#   'Cloudiness': 76,
#   'Wind Speed': 0.6,
#   'Country': 'ID'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64.99,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'ZA'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 50,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'JP'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 82.17,
#   'Current Description': 'scattered clouds',
#   'Humidity': 16,
#   'Cloudiness': 28,
#   'Wind Speed': 12.21,
#   'Country': 'MR'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 76.1,
#   'Current Description': 'few clouds',
#   'Humidity': 79,
#   'Cloudiness': 17,
#   'Wind Speed': 5.59,
#   'Country': 'BR'},
#  {'City': 'Kasongo-Lunda',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 70.99,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 89,
#   'Wind Speed': 0.76,
#   'Country': 'CD'},
#  {'City': 'Chumikan',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 17.55,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 2,
#   'Wind Speed': 16.49,
#   'Country': 'RU'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 33.8,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'IS'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 57.2,
#   'Current Description': 'broken clouds',
#   'Humidity': 33,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'CA'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 10.36,
#   'Current Description': 'broken clouds',
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 17.94,
#   'Country': 'RU'},
#  {'City': 'Mount Pleasant',
#   'Lat': 32.7941,
#   'Lng': -79.8626,
#   'Max Temp': 77,
#   'Current Description': 'clear sky',
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 14.5,
#   'Country': 'US'},
#  {'City': 'Erenhot',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 32.65,
#   'Current Description': 'overcast clouds',
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 23.42,
#   'Country': 'CN'},
#  {'City': 'Namtsy',
#   'Lat': 62.7161,
#   'Lng': 129.6658,
#   'Max Temp': 14,
#   'Current Description': 'light snow',
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 6.71,
#   'Country': 'RU'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -8.25,
#   'Current Description': 'clear sky',
#   'Humidity': 87,
#   'Cloudiness': 10,
#   'Wind Speed': 5.23,
#   'Country': 'RU'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 75.2,
#   'Current Description': 'scattered clouds',
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 30.2,
#   'Current Description': 'broken clouds',
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Country': 'CA'},
#  {'City': 'Bahia Blanca',
#   'Lat': -38.7196,
#   'Lng': -62.2724,
#   'Max Temp': 69.26,
#   'Current Description': 'clear sky',
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59,
#   'Country': 'AR'},
#  {'City': 'Tianpeng',
#   'Lat': 30.9866,
#   'Lng': 103.9393,
#   'Max Temp': 55.4,
#   'Current Description': 'mist',
#   'Humidity': 100,
#   'Cloudiness': 93,
#   'Wind Speed': 2.1,
#   'Country': 'CN'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 59,
#   'Current Description': 'broken clouds',
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'CL'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 73.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.14,
#   'Country': 'AU'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 10.58,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 91,
#   'Wind Speed': 7.23,
#   'Country': 'RU'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 30.2,
#   'Current Description': 'scattered clouds',
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Catalina',
#   'Lat': 32.5056,
#   'Lng': -110.9211,
#   'Max Temp': 88,
#   'Current Description': 'overcast clouds',
#   'Humidity': 10,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 81.18,
#   'Current Description': 'scattered clouds',
#   'Humidity': 81,
#   'Cloudiness': 45,
#   'Wind Speed': 9.22,
#   'Country': 'LR'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 60.8,
#   'Current Description': 'light rain',
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Country': 'AU'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 64.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 93,
#   'Wind Speed': 20.15,
#   'Country': 'UY'},
#  {'City': 'Lazaro Cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 82.96,
#   'Current Description': 'scattered clouds',
#   'Humidity': 56,
#   'Cloudiness': 25,
#   'Wind Speed': 12.01,
#   'Country': 'MX'},
#  {'City': 'Mariestad',
#   'Lat': 58.7097,
#   'Lng': 13.8237,
#   'Max Temp': 33.8,
#   'Current Description': 'light snow',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'SE'},
#  {'City': 'Virginia Beach',
#   'Lat': 36.8529,
#   'Lng': -75.978,
#   'Max Temp': 80.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 41,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 80.6,
#   'Current Description': 'scattered clouds',
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'BR'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 46,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 2,
#   'Wind Speed': 11.99,
#   'Country': 'PT'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 25,
#   'Current Description': 'snow',
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 28.77,
#   'Country': 'US'},
#  {'City': 'Belz',
#   'Lat': 47.6751,
#   'Lng': -3.168,
#   'Max Temp': 39,
#   'Current Description': 'clear sky',
#   'Humidity': 76,
#   'Cloudiness': 4,
#   'Wind Speed': 9.04,
#   'Country': 'FR'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 81.45,
#   'Current Description': 'clear sky',
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 9.75,
#   'Country': 'OM'},
#  {'City': 'Emba',
#   'Lat': 48.8264,
#   'Lng': 58.1442,
#   'Max Temp': 44.01,
#   'Current Description': 'clear sky',
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 9.75,
#   'Country': 'KZ'},
#  {'City': 'Ulverstone',
#   'Lat': -41.15,
#   'Lng': 146.1667,
#   'Max Temp': 48,
#   'Current Description': 'scattered clouds',
#   'Humidity': 81,
#   'Cloudiness': 47,
#   'Wind Speed': 13,
#   'Country': 'AU'},
#  {'City': 'Jizan',
#   'Lat': 17.3333,
#   'Lng': 42.6667,
#   'Max Temp': 84.2,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'SA'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 62.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'ZA'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 73.99,
#   'Current Description': 'scattered clouds',
#   'Humidity': 90,
#   'Cloudiness': 26,
#   'Wind Speed': 7,
#   'Country': 'PH'},
#  {'City': 'Tyup',
#   'Lat': 42.7276,
#   'Lng': 78.3648,
#   'Max Temp': 43.86,
#   'Current Description': 'clear sky',
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 3.15,
#   'Country': 'KG'},
#  {'City': 'Lakatoro',
#   'Lat': -16.0999,
#   'Lng': 167.4164,
#   'Max Temp': 79.84,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 95,
#   'Wind Speed': 2.8,
#   'Country': 'VU'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 78.8,
#   'Current Description': 'volcanic ash',
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'BB'},
#  {'City': 'Novyy Svit',
#   'Lat': 47.8059,
#   'Lng': 38.0211,
#   'Max Temp': 49.08,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Country': 'UA'},
#  {'City': 'Jiancheng',
#   'Lat': 30.391,
#   'Lng': 104.5491,
#   'Max Temp': 53.01,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'CN'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 53.11,
#   'Current Description': 'scattered clouds',
#   'Humidity': 95,
#   'Cloudiness': 38,
#   'Wind Speed': 3.89,
#   'Country': 'NZ'},
#  {'City': 'Rockingham',
#   'Lat': 42.9668,
#   'Lng': -71.0995,
#   'Max Temp': 50,
#   'Current Description': 'overcast clouds',
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 34,
#   'Current Description': 'mist',
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'CA'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 87.8,
#   'Current Description': 'broken clouds',
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'PF'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 25,
#   'Current Description': 'overcast clouds',
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Country': 'US'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 37.42,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 6.06,
#   'Country': 'GL'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 79.3,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 91,
#   'Wind Speed': 9.98,
#   'Country': 'VU'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 81.75,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'IN'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 82.51,
#   'Current Description': 'broken clouds',
#   'Humidity': 77,
#   'Cloudiness': 70,
#   'Wind Speed': 6.51,
#   'Country': 'AU'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 68.45,
#   'Current Description': 'scattered clouds',
#   'Humidity': 78,
#   'Cloudiness': 34,
#   'Wind Speed': 2.42,
#   'Country': 'NZ'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 35.6,
#   'Current Description': 'scattered clouds',
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'GL'},
#  {'City': 'Ouesso',
#   'Lat': 1.6136,
#   'Lng': 16.0517,
#   'Max Temp': 71.46,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 95,
#   'Wind Speed': 2.82,
#   'Country': 'CG'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -6.39,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 20.6,
#   'Country': 'RU'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 82.89,
#   'Current Description': 'clear sky',
#   'Humidity': 66,
#   'Cloudiness': 7,
#   'Wind Speed': 2.73,
#   'Country': 'MV'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 50,
#   'Current Description': 'clear sky',
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'GL'},
#  {'City': 'Kropotkin',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Country': 'RU'},
#  {'City': 'Tarakan',
#   'Lat': 3.3,
#   'Lng': 117.6333,
#   'Max Temp': 75.2,
#   'Current Description': 'broken clouds',
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'ID'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 82.4,
#   'Current Description': 'few clouds',
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'OM'},
#  {'City': 'Gushikawa',
#   'Lat': 26.3544,
#   'Lng': 127.8686,
#   'Max Temp': 69.8,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'JP'},
#  {'City': 'Kiama',
#   'Lat': -34.6833,
#   'Lng': 150.8667,
#   'Max Temp': 50,
#   'Current Description': 'few clouds',
#   'Humidity': 50,
#   'Cloudiness': 14,
#   'Wind Speed': 12.66,
#   'Country': 'AU'},
#  {'City': 'Palauig',
#   'Lat': 15.435,
#   'Lng': 119.9045,
#   'Max Temp': 78.31,
#   'Current Description': 'broken clouds',
#   'Humidity': 70,
#   'Cloudiness': 57,
#   'Wind Speed': 3.71,
#   'Country': 'PH'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 82.38,
#   'Current Description': 'scattered clouds',
#   'Humidity': 61,
#   'Cloudiness': 47,
#   'Wind Speed': 11.07,
#   'Country': 'SO'},
#  {'City': 'Itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 69.8,
#   'Current Description': 'few clouds',
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'JP'},
#  {'City': 'Huambo',
#   'Lat': -12.7761,
#   'Lng': 15.7392,
#   'Max Temp': 60.98,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'AO'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 66,
#   'Current Description': 'overcast clouds',
#   'Humidity': 63,
#   'Cloudiness': 86,
#   'Wind Speed': 18.41,
#   'Country': 'US'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 78.4,
#   'Current Description': 'moderate rain',
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 12.12,
#   'Country': 'PG'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 78.8,
#   'Current Description': 'scattered clouds',
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'MU'},
#  {'City': 'Hohhot',
#   'Lat': 40.8106,
#   'Lng': 111.6522,
#   'Max Temp': 41,
#   'Current Description': 'light rain',
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 17.9,
#   'Country': 'CN'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 79,
#   'Current Description': 'light rain',
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Country': 'MU'},
#  {'City': 'Okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 22.17,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 14.23,
#   'Country': 'RU'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 57.2,
#   'Current Description': 'overcast clouds',
#   'Humidity': 54,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'AU'},
#  {'City': 'Mungwi',
#   'Lat': -10.1732,
#   'Lng': 31.3694,
#   'Max Temp': 61.02,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 5.08,
#   'Country': 'ZM'},
#  {'City': 'Balkanabat',
#   'Lat': 39.5108,
# ...
#   'Cloudiness': 85,
#   'Wind Speed': 2.3,
#   'Country': 'CG'},
#  {'City': 'Bam',
#   'Lat': 29.106,
#   'Lng': 58.357,
#   'Max Temp': 76.14,
#   'Current Description': 'few clouds',
#   'Humidity': 16,
#   'Cloudiness': 15,
#   'Wind Speed': 10.69,
#   'Country': 'IR'},
#  {'City': 'Awbari',
#   'Lat': 26.5921,
#   'Lng': 12.7805,
#   'Max Temp': 82.49,
#   'Current Description': 'scattered clouds',
#   'Humidity': 12,
#   'Cloudiness': 46,
#   'Wind Speed': 18.63,
#   'Country': 'LY'},
#  {'City': 'Madona',
#   'Lat': 56.8533,
#   'Lng': 26.217,
#   'Max Temp': 44.24,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 6.06,
#   'Country': 'LV'},
#  {'City': 'Lhokseumawe',
#   'Lat': 5.1801,
#   'Lng': 97.1507,
#   'Max Temp': 77.11,
#   'Current Description': 'few clouds',
#   'Humidity': 85,
#   'Cloudiness': 21,
#   'Wind Speed': 3.53,
#   'Country': 'ID'},
#  {'City': 'Piranhas',
#   'Lat': -16.4269,
#   'Lng': -51.8222,
#   'Max Temp': 78.33,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'BR'},
#  {'City': 'Tra Vinh',
#   'Lat': 9.9347,
#   'Lng': 106.3453,
#   'Max Temp': 80.15,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 72,
#   'Wind Speed': 9.04,
#   'Country': 'VN'},
#  {'City': 'Aksay',
#   'Lat': 47.26,
#   'Lng': 39.87,
#   'Max Temp': 46.99,
#   'Current Description': 'broken clouds',
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 11.18,
#   'Country': 'RU'},
#  {'City': 'Pocone',
#   'Lat': -16.2567,
#   'Lng': -56.6228,
#   'Max Temp': 85.69,
#   'Current Description': 'heavy intensity rain',
#   'Humidity': 51,
#   'Cloudiness': 66,
#   'Wind Speed': 7.11,
#   'Country': 'BR'},
#  {'City': 'Katherine',
#   'Lat': -14.4667,
#   'Lng': 132.2667,
#   'Max Temp': 71.6,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 65,
#   'Wind Speed': 4.61,
#   'Country': 'AU'},
#  {'City': 'Grafton',
#   'Lat': 42.207,
#   'Lng': -71.6856,
#   'Max Temp': 48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 29.19,
#   'Current Description': 'clear sky',
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 5.06,
#   'Country': 'MN'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 57.2,
#   'Current Description': 'clear sky',
#   'Humidity': 54,
#   'Cloudiness': 7,
#   'Wind Speed': 10.36,
#   'Country': 'AU'},
#  {'City': 'Susacon',
#   'Lat': 6.2298,
#   'Lng': -72.6901,
#   'Max Temp': 64.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 71,
#   'Cloudiness': 86,
#   'Wind Speed': 2.46,
#   'Country': 'CO'},
#  {'City': 'Manaure',
#   'Lat': 11.7751,
#   'Lng': -72.4445,
#   'Max Temp': 86.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 59,
#   'Cloudiness': 98,
#   'Wind Speed': 15.84,
#   'Country': 'CO'},
#  {'City': 'Wichita Falls',
#   'Lat': 33.9137,
#   'Lng': -98.4934,
#   'Max Temp': 86,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Burnie',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 48,
#   'Current Description': 'scattered clouds',
#   'Humidity': 83,
#   'Cloudiness': 39,
#   'Wind Speed': 15.99,
#   'Country': 'AU'},
#  {'City': 'Baijiantan',
#   'Lat': 45.6333,
#   'Lng': 85.1833,
#   'Max Temp': 51.94,
#   'Current Description': 'clear sky',
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 3.47,
#   'Country': 'CN'},
#  {'City': 'Caucaia',
#   'Lat': -3.7361,
#   'Lng': -38.6531,
#   'Max Temp': 80.01,
#   'Current Description': 'few clouds',
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'BR'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 57.99,
#   'Current Description': 'scattered clouds',
#   'Humidity': 81,
#   'Cloudiness': 49,
#   'Wind Speed': 1.01,
#   'Country': 'NZ'},
#  {'City': 'Masty',
#   'Lat': 53.4122,
#   'Lng': 24.5387,
#   'Max Temp': 51.33,
#   'Current Description': 'overcast clouds',
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 14.09,
#   'Country': 'BY'},
#  {'City': 'Sovetskiy',
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp': 33.39,
#   'Current Description': 'few clouds',
#   'Humidity': 91,
#   'Cloudiness': 16,
#   'Wind Speed': 7.49,
#   'Country': 'RU'},
#  {'City': 'Lamar',
#   'Lat': 33.6668,
#   'Lng': -95.5836,
#   'Max Temp': 80.6,
#   'Current Description': 'clear sky',
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Biryusinsk',
#   'Lat': 55.9634,
#   'Lng': 97.8235,
#   'Max Temp': 31.26,
#   'Current Description': 'light snow',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.66,
#   'Country': 'RU'},
#  {'City': 'Candido Mota',
#   'Lat': -22.7464,
#   'Lng': -50.3869,
#   'Max Temp': 79.12,
#   'Current Description': 'clear sky',
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 3.27,
#   'Country': 'BR'},
#  {'City': 'Mibu',
#   'Lat': 36.4167,
#   'Lng': 139.8,
#   'Max Temp': 54,
#   'Current Description': 'few clouds',
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'JP'},
#  {'City': 'Harduaganj',
#   'Lat': 27.95,
#   'Lng': 78.1667,
#   'Max Temp': 79.92,
#   'Current Description': 'clear sky',
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 6.35,
#   'Country': 'IN'},
#  {'City': 'Roura',
#   'Lat': 4.7263,
#   'Lng': -52.3274,
#   'Max Temp': 84.2,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'GF'},
#  {'City': 'Shache',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 55.29,
#   'Current Description': 'scattered clouds',
#   'Humidity': 24,
#   'Cloudiness': 26,
#   'Wind Speed': 4.7,
#   'Country': 'CN'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 2.84,
#   'Current Description': 'snow',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 24.23,
#   'Country': 'RU'},
#  {'City': 'Bayanday',
#   'Lat': 53.0661,
#   'Lng': 105.5139,
#   'Max Temp': 21.78,
#   'Current Description': 'few clouds',
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 3.51,
#   'Country': 'RU'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 66.96,
#   'Current Description': 'clear sky',
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 15.05,
#   'Country': 'EG'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 54,
#   'Current Description': 'clear sky',
#   'Humidity': 57,
#   'Cloudiness': 3,
#   'Wind Speed': 3,
#   'Country': 'AU'},
#  {'City': 'Barcelos',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 59,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'PT'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 57.2,
#   'Current Description': 'scattered clouds',
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Lomovka',
#   'Lat': 53.9194,
#   'Lng': 58.3672,
#   'Max Temp': 35.6,
#   'Current Description': 'mist',
#   'Humidity': 100,
#   'Cloudiness': 86,
#   'Wind Speed': 11.18,
#   'Country': 'RU'},
#  {'City': 'Sanchor',
#   'Lat': 24.7553,
#   'Lng': 71.7722,
#   'Max Temp': 79.95,
#   'Current Description': 'clear sky',
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 8.86,
#   'Country': 'IN'},
#  {'City': 'Starachowice',
#   'Lat': 51.0374,
#   'Lng': 21.0713,
#   'Max Temp': 54,
#   'Current Description': 'overcast clouds',
#   'Humidity': 1,
#   'Cloudiness': 100,
#   'Wind Speed': 11.88,
#   'Country': 'PL'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 84,
#   'Current Description': 'clear sky',
#   'Humidity': 9,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Elko',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': 57,
#   'Current Description': 'clear sky',
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'US'},
#  {'City': 'Sidi Ali',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 56.43,
#   'Current Description': 'scattered clouds',
#   'Humidity': 83,
#   'Cloudiness': 30,
#   'Wind Speed': 2.17,
#   'Country': 'DZ'},
#  {'City': 'Hun',
#   'Lat': 29.1268,
#   'Lng': 15.9477,
#   'Max Temp': 72.03,
#   'Current Description': 'overcast clouds',
#   'Humidity': 13,
#   'Cloudiness': 98,
#   'Wind Speed': 20,
#   'Country': 'LY'},
#  {'City': 'Grand-Lahou',
#   'Lat': 5.1367,
#   'Lng': -5.0242,
#   'Max Temp': 81.72,
#   'Current Description': 'scattered clouds',
#   'Humidity': 87,
#   'Cloudiness': 27,
#   'Wind Speed': 11.97,
#   'Country': 'CI'},
#  {'City': 'Bintulu',
#   'Lat': 3.1667,
#   'Lng': 113.0333,
#   'Max Temp': 77,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'MY'},
#  {'City': 'Lakefield',
#   'Lat': 43.6775,
#   'Lng': -95.1717,
#   'Max Temp': 55.99,
#   'Current Description': 'clear sky',
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 21.85,
#   'Country': 'US'},
#  {'City': 'Santa Fe',
#   'Lat': -31.6333,
#   'Lng': -60.7,
#   'Max Temp': 64.78,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 98,
#   'Wind Speed': 9.53,
#   'Country': 'AR'},
#  {'City': 'Abu Dhabi',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 86,
#   'Current Description': 'clear sky',
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AE'},
#  {'City': 'Wad Madani',
#   'Lat': 14.4012,
#   'Lng': 33.5199,
#   'Max Temp': 87.24,
#   'Current Description': 'clear sky',
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 17.09,
#   'Country': 'SD'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 50,
#   'Current Description': 'clear sky',
#   'Humidity': 50,
#   'Cloudiness': 5,
#   'Wind Speed': 12.66,
#   'Country': 'AU'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 68,
#   'Current Description': 'clear sky',
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'MR'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 80.55,
#   'Current Description': 'broken clouds',
#   'Humidity': 85,
#   'Cloudiness': 58,
#   'Wind Speed': 1.23,
#   'Country': 'GA'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 24.8,
#   'Current Description': 'few clouds',
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 64.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 9.42,
#   'Country': 'PT'},
#  {'City': 'Lerwick',
#   'Lat': 60.1545,
#   'Lng': -1.1494,
#   'Max Temp': 35.6,
#   'Current Description': 'broken clouds',
#   'Humidity': 75,
#   'Cloudiness': 51,
#   'Wind Speed': 10.36,
#   'Country': 'GB'},
#  {'City': 'Santa Cruz Del Sur',
#   'Lat': 20.7147,
#   'Lng': -77.9956,
#   'Max Temp': 83.23,
#   'Current Description': 'broken clouds',
#   'Humidity': 67,
#   'Cloudiness': 57,
#   'Wind Speed': 13.09,
#   'Country': 'CU'},
#  {'City': 'Karoi',
#   'Lat': -16.8099,
#   'Lng': 29.6925,
#   'Max Temp': 60.01,
#   'Current Description': 'clear sky',
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 3.65,
#   'Country': 'ZW'},
#  {'City': 'Teya',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 16.03,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 3.11,
#   'Country': 'RU'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 81.99,
#   'Current Description': 'clear sky',
#   'Humidity': 39,
#   'Cloudiness': 3,
#   'Wind Speed': 10.76,
#   'Country': 'GM'},
#  {'City': 'Birjand',
#   'Lat': 32.8663,
#   'Lng': 59.2211,
#   'Max Temp': 64.4,
#   'Current Description': 'clear sky',
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'IR'},
#  {'City': 'Hutchinson',
#   'Lat': 38.0608,
#   'Lng': -97.9298,
#   'Max Temp': 80.6,
#   'Current Description': 'clear sky',
#   'Humidity': 18,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'US'},
#  {'City': 'Bastia',
#   'Lat': 42.6667,
#   'Lng': 9.3333,
#   'Max Temp': 59,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'FR'},
#  {'City': 'Ipixuna',
#   'Lat': -1.7625,
#   'Lng': -48.8043,
#   'Max Temp': 75.2,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'BR'},
#  {'City': 'Montepulciano',
#   'Lat': 43.1017,
#   'Lng': 11.7868,
#   'Max Temp': 53.01,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'IT'},
#  {'City': 'Tripoli',
#   'Lat': 32.8752,
#   'Lng': 13.1875,
#   'Max Temp': 65.98,
#   'Current Description': 'overcast clouds',
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 25.12,
#   'Country': 'LY'},
#  {'City': 'Abonnema',
#   'Lat': 4.7084,
#   'Lng': 6.7931,
#   'Max Temp': 80.6,
#   'Current Description': 'few clouds',
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.35,
#   'Country': 'NG'},
#  {'City': 'Raga',
#   'Lat': 8.4596,
#   'Lng': 25.678,
#   'Max Temp': 85.15,
#   'Current Description': 'overcast clouds',
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 1.77,
#   'Country': 'SS'},
#  {'City': 'Karlstad',
#   'Lat': 59.3793,
#   'Lng': 13.5036,
#   'Max Temp': 32,
#   'Current Description': 'snow',
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'SE'},
#  {'City': 'Karaton',
#   'Lat': -6.3424,
#   'Lng': 106.1045,
#   'Max Temp': 78.01,
#   'Current Description': 'few clouds',
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'ID'},
#  {'City': 'Pindiga',
#   'Lat': 9.9833,
#   'Lng': 10.9333,
#   'Max Temp': 88.84,
#   'Current Description': 'overcast clouds',
#   'Humidity': 32,
#   'Cloudiness': 95,
#   'Wind Speed': 6.11,
#   'Country': 'NG'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 77.47,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Country': 'PH'},
#  {'City': 'Tatarsk',
#   'Lat': 55.219,
#   'Lng': 75.9828,
#   'Max Temp': 26.33,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 91,
#   'Wind Speed': 7.14,
#   'Country': 'RU'},
#  {'City': 'Camargo',
#   'Lat': 27.6667,
#   'Lng': -105.1667,
#   'Max Temp': 86.25,
#   'Current Description': 'overcast clouds',
#   'Humidity': 7,
#   'Cloudiness': 100,
#   'Wind Speed': 5.44,
#   'Country': 'MX'},
#  {'City': 'Bom Conselho',
#   'Lat': -9.1697,
#   'Lng': -36.6797,
#   'Max Temp': 69.31,
#   'Current Description': 'light rain',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.98,
#   'Country': 'BR'},
#  {'City': 'Karasjok',
#   'Lat': 69.4719,
#   'Lng': 25.5112,
#   'Max Temp': 33.8,
#   'Current Description': 'few clouds',
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Country': 'NO'},
#  {'City': 'Katete',
#   'Lat': -0.7818,
#   'Lng': 29.7544,
#   'Max Temp': 60.1,
#   'Current Description': 'scattered clouds',
#   'Humidity': 87,
#   'Cloudiness': 28,
#   'Wind Speed': 3.78,
#   'Country': 'UG'},
#  {'City': 'Svetlogorsk',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 45.68,
#   'Current Description': 'clear sky',
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 6.62,
#   'Country': 'BY'},
#  {'City': 'Benghazi',
#   'Lat': 32.1167,
#   'Lng': 20.0667,
#   'Max Temp': 62.62,
#   'Current Description': 'scattered clouds',
#   'Humidity': 46,
#   'Cloudiness': 25,
#   'Wind Speed': 11.39,
#   'Country': 'LY'},
#  {'City': 'Viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 69.93,
#   'Current Description': 'clear sky',
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 7.96,
#   'Country': 'AR'},
#  {'City': 'Varlamovo',
#   'Lat': 53.1897,
#   'Lng': 48.4226,
#   'Max Temp': 45.57,
#   'Current Description': 'overcast clouds',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Country': 'RU'},
#  {'City': 'Jati',
#   'Lat': 24.3539,
#   'Lng': 68.2671,
#   'Max Temp': 79.05,
#   'Current Description': 'clear sky',
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 14.07,
#   'Country': 'PK'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': -15.84,
#   'Current Description': 'broken clouds',
#   'Humidity': 97,
#   'Cloudiness': 64,
#   'Wind Speed': 6.6,
#   'Country': 'RU'}]

# %%
weather_data_df = pd.DataFrame(city_data)
weather_data_df
# Out:
#                City      Lat       Lng  Max Temp Current Description  \
# 0            Hobart -42.8794  147.3294     48.99       broken clouds
# 1    Cabo San Lucas  22.8909 -109.9124     84.00       broken clouds
# 2      Punta Arenas -53.1500  -70.9167     57.20           clear sky
# 3        Rio Grande -32.0350  -52.0986     71.60     overcast clouds
# 4         Filipesti  46.7500   26.8833     43.00          light rain
# ..              ...      ...       ...       ...                 ...
# 719        Benghazi  32.1167   20.0667     62.62    scattered clouds
# 720          Viedma -40.8135  -62.9967     69.93           clear sky
# 721       Varlamovo  53.1897   48.4226     45.57     overcast clouds
# 722            Jati  24.3539   68.2671     79.05           clear sky
# 723       Ust-Kuyga  70.0167  135.6000    -15.84       broken clouds
#
#      Humidity  Cloudiness  Wind Speed Country
# 0          81          75       11.50      AU
# 1          34          75       11.50      MX
# 2          38           0       10.36      CL
# 3          83          90       20.71      BR
# 4          52           0        9.22      RO
# ..        ...         ...         ...     ...
# 719        46          25       11.39      LY
# 720        31           0        7.96      AR
# 721        93         100        6.60      RU
# 722        60           0       14.07      PK
# 723        97          64        6.60      RU
#
# [724 rows x 9 columns]

# %%
reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
weather_data_df = weather_data_df[reorder]
weather_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hobart      AU -42.8794  147.3294     48.99        81
# 1    Cabo San Lucas      MX  22.8909 -109.9124     84.00        34
# 2      Punta Arenas      CL -53.1500  -70.9167     57.20        38
# 3        Rio Grande      BR -32.0350  -52.0986     71.60        83
# 4         Filipesti      RO  46.7500   26.8833     43.00        52
# ..              ...     ...      ...       ...       ...       ...
# 719        Benghazi      LY  32.1167   20.0667     62.62        46
# 720          Viedma      AR -40.8135  -62.9967     69.93        31
# 721       Varlamovo      RU  53.1897   48.4226     45.57        93
# 722            Jati      PK  24.3539   68.2671     79.05        60
# 723       Ust-Kuyga      RU  70.0167  135.6000    -15.84        97
#
#      Cloudiness  Wind Speed Current Description
# 0            75       11.50       broken clouds
# 1            75       11.50       broken clouds
# 2             0       10.36           clear sky
# 3            90       20.71     overcast clouds
# 4             0        9.22          light rain
# ..          ...         ...                 ...
# 719          25       11.39    scattered clouds
# 720           0        7.96           clear sky
# 721         100        6.60     overcast clouds
# 722           0       14.07           clear sky
# 723          64        6.60       broken clouds
#
# [724 rows x 9 columns]

# %%
export_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(export_data_file, index_label="City_ID")
